# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.funciones import sumar_estadisticas
from src.funciones import calcular_mvp
from src.funciones import inicializar_en0
from src.funciones import imprimir_porronda
from src.funciones import imprimir_rondafinal

rounds = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]


ronda_final ={
'Shadow': {'kills': 0, 'assists': 0, 'MVPs' : 0, 'deaths': 0, 'puntos': 0},
'Blaze': {'kills': 0, 'assists': 0, 'MVPs' : 0, 'deaths': 0, 'puntos': 0},
'Viper': {'kills': 0, 'assists': 0, 'MVPs' : 0, 'deaths': 0, 'puntos': 0},
'Frost': {'kills': 0, 'assists': 0, 'MVPs' : 0, 'deaths': 0, 'puntos': 0},
'Reaper': {'kills': 0, 'assists': 0, 'MVPs': 0, 'deaths': 0, 'puntos': 0}
}

mvp_porpartida ={
'Shadow': 0,
'Blaze': 0,
'Viper': 0,
'Frost': 0,
'Reaper': 0
}

def ordenar_ronda(elem):
    elem = dict(sorted(elem.items(), key=lambda item: item[1]['kills'], reverse=True))
    return elem

def ordenar_rondafinal(elem):
    elem = dict(sorted(elem.items(), key=lambda item: item[1]['puntos'], reverse=True))
    return elem

ronda = 0
for elem in rounds:
    ronda +=1
    for jugador in elem:
        stats = elem[jugador]
        for estadistica in stats:
            sumar_estadisticas(ronda_final,mvp_porpartida,estadistica,stats,jugador)
    calcular_mvp(ronda_final,mvp_porpartida)
    elem = ordenar_ronda(elem)
    imprimir_porronda(elem,mvp_porpartida,ronda)
    inicializar_en0(mvp_porpartida)
    
ronda_final = ordenar_rondafinal(ronda_final)
imprimir_rondafinal(ronda_final)
# Out:
# Ranking ronda 1
#  jugador   kills   asistencias   muertes
# -----------------------------------------
#  Shadow      2          1         True
#
#  Blaze      1          0         False
#
#  Viper      1          2         True
#
#  Reaper      1          1         False
#
#  Frost      0          1         False
#
# -----------------------------------------
#
#
# Ranking ronda 2
#  jugador   kills   asistencias   muertes
# -----------------------------------------
#  Blaze      2          0         True
#
#  Frost      2          1         True
#
#  Viper      1          1         False
#
#  Shadow      0          2         False
#
#  Reaper      0          1         False
#
# -----------------------------------------
#
#
# Ranking ronda 3
#  jugador   kills   asistencias   muertes
# -----------------------------------------
#  Blaze      2          2         True
#
#  Shadow      1          0         False
#
#  Viper      1          1         True
#
# ...
